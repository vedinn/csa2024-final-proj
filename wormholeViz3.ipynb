# %% [markdown]
# # Wormhole visualizer

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import ipywidgets
# %matplotlib ipympl

from matplotlib import cm
from matplotlib.ticker import LinearLocator

# %%
plt.figure()
r = np.linspace(-5,5,100)
f = np.sqrt( 1/(1+np.exp(-abs(r))) - 0.5 - 0.2 )*3.5
plt.plot(r, f)
# Out:
# C:\Users\sylvi\AppData\Local\Temp\ipykernel_118620\429464241.py:3: RuntimeWarning: invalid value encountered in sqrt
#   f = np.sqrt( 1/(1+np.exp(-abs(r))) - 0.5 - 0.2 )*3.5
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.linspace(-5, 5, 1000)
Y = np.linspace(-5, 5, 1000)
Xm, Ym = np.meshgrid(X, Y)
Rm = np.sqrt(Xm**2 + Ym**2)
Zm = np.sqrt( 1/(1+np.exp(-Rm)) - 0.5 - 0.2 )*5

# Plot the surface.
surf = ax.plot_surface(Xm, Ym, Zm, cmap=cm.coolwarm,
                       linewidth=0, antialiased=True)
surf = ax.plot_surface(Xm, Ym, -Zm, cmap=cm.coolwarm_r,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-2.01, 2.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# C:\Users\sylvi\AppData\Local\Temp\ipykernel_118620\731088514.py:8: RuntimeWarning: invalid value encountered in sqrt
#   Zm = np.sqrt( 1/(1+np.exp(-Rm)) - 0.5 - 0.2 )*5
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
interact(
    simulate,
    first = -5, 
    second = 5, 
    res = widgets.IntSlider(min = 5, max = 30, step = 1, value = 10),
    length = widgets.IntSlider(min=1, max = 10, step = 1, value = 1)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 interact(
# ----> 2     simulate,
#       3     r = 5,
#       4     outer_r = 30,
#       5     res = widgets.IntSlider(min = 5, max = 30, step = 1, value = 10),
#       6     length = widgets.IntSlider(min=1, max = 10, step = 1, value = 1)
#       7 )
#
# NameError: name 'simulate' is not defined
